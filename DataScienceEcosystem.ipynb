# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# Exercise 2 - Title of the Notebook

# %% [raw]
# This notebook is titled "Data Science Exploration Notebook."

# %% [markdown]
# Exercise 3 - Introduction

# %% [raw]
# Welcome to this Data Science Exploration Notebook!
# In this notebook, we will look at a variety of data science ideas and applications.
# We'll go through programming languages, libraries, tools, arithmetic expressions, and more.
# Let's go on an adventure of discovery and learning!

# %% [markdown]
# Exercise 4 - Data Science Languages

# %% [raw]
# Here are some prominent programming languages used in data science:
#
# ->Python
# ->R
# ->Julia
# ->SQL

# %% [markdown]
# Exercise 5 - Data Science Libraries

# %% [raw]
# Several libraries enhance data science workflows. Some of them include:
#
# ->NumPy
# ->pandas
# ->Matplotlib
# ->Seaborn
# ->scikit-learn

# %% [markdown]
# Exercise 6 - Data Science Tools

# %% [raw]
# Here's a table of common Data Science tools:
# ___________________________________________________
# | Tool          | Purpose                         |
# |---------------|---------------------------------|
# | Jupyter       | Interactive coding environment  |
# | Git           | Version control                 |
# | Docker        | Containerization                |
# | Tableau       | Data visualization              |
# | TensorFlow    | Machine learning framework      |
# ___________________________________________________

# %% [markdown]
# Exercise 7 - Arithmetic Expression Examples

# %% [raw]
# In data science, arithmetic expressions are essential. They include addition, subtraction, multiplication, and division.

# %% [markdown]
# Exercise 8 - Multiplication and Addition

# %%
result = 2*3+4
print(result)
# Out:
# 10

# %% [markdown]
# Exercise 9 - Convert Minutes to Hours

# %%
minutes = 200
hours = minutes / 60
print(hours)
# Out:
# 3.3333333333333335

# %% [markdown]
# Exercise 10 - Objectives

# %% [raw]
# The following are the aims of this notebook:
#
# ->Discover key data science topics.
# ->Discover popular programming languages and libraries.
# ->Understand mathematical expressions and how to apply them.
# ->Introduce several data science tools.
# ->Share insights through visualizations.

# %% [markdown]
# Exercise 11 - Author's Name

# %% [raw]
# Author :Atharva Puranik

# %% [markdown]
# Exercise 12 - Sharing on GitHub

# %% [raw]
# This notebook has been shared on GitHub at https://github.com/Atharvapuranik12

# %% [markdown]
# Exercise 13 - Screenshot

# %% [markdown]
# ![1-notebook.png](attachment:5e828e19-b526-4868-8e58-6437983bf350.png)
